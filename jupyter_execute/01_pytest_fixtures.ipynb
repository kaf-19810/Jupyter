# %% [markdown]
# # `pytest`测试框架的fixture高效使用

# %% [markdown]
# 在笔记本电脑中使用`pytest`所需的样板。

# %%
# 让我们确保安装了pytest和ipytest包
# 在Jupyter notebooks中运行pytest需要ipytest模块
import sys

# !{sys.executable} -m pip install pytest
# !{sys.executable} -m pip install ipytest

# 在Jupyter notebooks中运行pytest需要这些
import ipytest

ipytest.autoconfig()

import pytest
# Out:
# Requirement already satisfied: pytest in /home/kaf/myenv/lib/python3.11/site-packages (8.3.3)
# Requirement already satisfied: iniconfig in /home/kaf/myenv/lib/python3.11/site-packages (from pytest) (2.0.0)
# Requirement already satisfied: packaging in /home/kaf/myenv/lib/python3.11/site-packages (from pytest) (24.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/kaf/myenv/lib/python3.11/site-packages (from pytest) (1.5.0)
# Requirement already satisfied: ipytest in /home/kaf/myenv/lib/python3.11/site-packages (0.14.2)
# Requirement already satisfied: ipython in /home/kaf/myenv/lib/python3.11/site-packages (from ipytest) (8.29.0)
# Requirement already satisfied: packaging in /home/kaf/myenv/lib/python3.11/site-packages (from ipytest) (24.2)
# Requirement already satisfied: pytest>=5.4 in /home/kaf/myenv/lib/python3.11/site-packages (from ipytest) (8.3.3)
# Requirement already satisfied: iniconfig in /home/kaf/myenv/lib/python3.11/site-packages (from pytest>=5.4->ipytest) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/kaf/myenv/lib/python3.11/site-packages (from pytest>=5.4->ipytest) (1.5.0)
# Requirement already satisfied: decorator in /home/kaf/myenv/lib/python3.11/site-packages (from ipython->ipytest) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/kaf/myenv/lib/python3.11/site-packages (from ipython->ipytest) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/kaf/myenv/lib/python3.11/site-packages (from ipython->ipytest) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/kaf/myenv/lib/python3.11/site-packages (from ipython->ipytest) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /home/kaf/myenv/lib/python3.11/site-packages (from ipython->ipytest) (2.18.0)
# Requirement already satisfied: stack-data in /home/kaf/myenv/lib/python3.11/site-packages (from ipython->ipytest) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/kaf/myenv/lib/python3.11/site-packages (from ipython->ipytest) (5.14.3)
# Requirement already satisfied: typing-extensions>=4.6 in /home/kaf/myenv/lib/python3.11/site-packages (from ipython->ipytest) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /home/kaf/myenv/lib/python3.11/site-packages (from ipython->ipytest) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/kaf/myenv/lib/python3.11/site-packages (from jedi>=0.16->ipython->ipytest) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/kaf/myenv/lib/python3.11/site-packages (from pexpect>4.3->ipython->ipytest) (0.7.0)
# Requirement already satisfied: wcwidth in /home/kaf/myenv/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ipytest) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/kaf/myenv/lib/python3.11/site-packages (from stack-data->ipython->ipytest) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/kaf/myenv/lib/python3.11/site-packages (from stack-data->ipython->ipytest) (2.4.1)
# Requirement already satisfied: pure-eval in /home/kaf/myenv/lib/python3.11/site-packages (from stack-data->ipython->ipytest) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /home/kaf/myenv/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython->ipytest) (1.16.0)

# %% [markdown]
# ## fixtures参数化
# 与使用`pytest.mark.parameterize`参数化测试函数类似，您也可以参数化fixtures:

# %%
PATHS = ["/foo/bar.txt", "/bar/baz.txt"]


@pytest.fixture(params=PATHS)
def executable(request):
    return request.param

# %%
# %%ipytest -s
#
# def test_something_with_executable(executable):
#     print(executable)
# Out:
# /foo/bar.txt
# .
# /bar/baz.txt
# .
# 2 passed in 0.01s

# %% [markdown]
# ## [`pytest.mark.usefixtures`](https://docs.pytest.org/en/latest/fixture.html#usefixtures)
# [`pytest.mark.usefixtures`](https://docs.pytest.org/en/latest/fixture.html#usefixtures) 非常有用，特别是当您想在一组测试中使用某个fixture，但不需要fixture的返回值时。

# %%
# %%ipytest -s
#
#
# @pytest.fixture
# def my_fixture():
#     print("\nmy_fixture is used")
#
#
# @pytest.fixture
# def other_fixture():
#     return "FOO"
#
#
# @pytest.mark.usefixtures('my_fixture')
# class TestMyStuff:
#     def test_somestuff(self):
#         pass
#
#     def test_some_other_stuff(self, other_fixture):
#         print(f'here we use also other_fixture which returns: {other_fixture}')
# Out:
# my_fixture is used
# .
# my_fixture is used
# here we use also other_fixture which returns: FOO
# .
# 2 passed in 0.02s

# %% [markdown]
# ## `pytest` [内置 fixtures](https://docs.pytest.org/en/latest/builtin.html#pytest-api-and-builtin-fixtures)
# 这里有几个有用的内置fixtures的示例，您可以通过运行`pytest --fixtures`来查看所有可用的fixtures。

# %% [markdown]
# ### [`monkeypatch（猴子补丁）`](https://docs.pytest.org/en/latest/reference.html#_pytest.monkeypatch.MonkeyPatch)
# 内置[`monkeypatch`](https://docs.pytest.org/en/latest/reference.html#_pytest.monkeypatch.MonkeyPatch) fixture允许您设置环境变量和设置/删除对象的属性。用例类似于使用patching/mocking进行补丁/模拟。 `unittest.mock.patch`/`unittest.mock.MagicMock` 是Python标准库的一部分。
#
# **Monkey匹配环境变量：**

# %%
import os


def get_env_var_or_none(var_name):
    return os.environ.get(var_name, None)

# %%
# %%ipytest -s
#
# def test_get_env_var_or_none_with_valid_env_var(monkeypatch):
#     monkeypatch.setenv('MY_ENV_VAR', 'secret')
#     res = get_env_var_or_none('MY_ENV_VAR')
#     assert res == 'secret'
#
# def test_get_env_var_or_none_with_missing_env_var():
#     res = get_env_var_or_none('NOT_EXISTING')
#     assert res is None
# Out:
# .
# .
# 2 passed in 0.01s

# %% [markdown]
# **Monkeypatching 属性:**

# %%
class SomeClass:
    some_value = "some value"

    @staticmethod
    def tell_the_truth():
        print("This is the original truth")

# %%
def fake_truth():
    print("This is modified truth")


@pytest.fixture
def fake_some_class(monkeypatch):
    monkeypatch.setattr("__main__.SomeClass.some_value", "fake value")
    monkeypatch.setattr("__main__.SomeClass.tell_the_truth", fake_truth)

# %%
# %%ipytest -s
#
# def test_some_class(fake_some_class):
#     print(SomeClass.some_value)
#     SomeClass.tell_the_truth()
# Out:
# fake value
# This is modified truth
# .
# 1 passed in 0.01s

# %% [markdown]
# ### [`tmpdir`](https://docs.pytest.org/en/latest/tmpdir.html#the-tmpdir-fixture)
# [`tmpdir`](https://docs.pytest.org/en/latest/tmpdir.html#the-tmpdir-fixture) fixture 提供创建临时文件和目录的功能。

# %%
def word_count_of_txt_file(file_path):
    with open(file_path) as f:
        content = f.read()
        return len(content.split())

# %%
# %%ipytest -s
#
# def test_word_count(tmpdir):
#     test_file = tmpdir.join('test.txt')
#     test_file.write('This is example content of seven words')
#     res = word_count_of_txt_file(str(test_file)) # str返回路径
#     assert res == 7
# Out:
# .
# 1 passed in 0.03s

# %% [markdown]
# ## Fixture 作用范围

# %%
@pytest.fixture(scope="function")
def func_fixture():
    print("\nfunc")


@pytest.fixture(scope="module")
def module_fixture():
    print("\nmodule")


@pytest.fixture(scope="session")
def session_fixture():
    print("\nsession")

# %%
# %%ipytest -s
#
# def test_something(func_fixture, module_fixture, session_fixture):
#     pass
#
# def test_something_else(func_fixture, module_fixture, session_fixture):
#     pass
# Out:
# session
#
# module
#
# func
# .
# func
# .
# 2 passed in 0.03s

# %% [markdown]
# ## 前置-后置行为

# %%
@pytest.fixture
def some_fixture():
    print("some_fixture is run now")
    yield "some magical value"
    print("\nthis will be run after test execution, you can do e.g. some clean up here")

# %%
# %%ipytest -s
#
# def test_something(some_fixture):
#     print('running test_something')
#     assert some_fixture == 'some magical value'
#     print('test ends here')
# Out:
# some_fixture is run now
# running test_something
# test ends here
# .
# this will be run after test execution, you can do e.g. some clean up here
#
# 1 passed in 0.03s

# %% [markdown]
# ## 自动使用 fixtures

# %%
@pytest.fixture(autouse=True)
def my_fixture():
    print("\nusing my_fixture")

# %%
# %%ipytest -s
#
# def test_1():
#     pass
#
# def test_2():
#     pass
# Out:
# using my_fixture
# .
# using my_fixture
# .
# 2 passed in 0.03s
